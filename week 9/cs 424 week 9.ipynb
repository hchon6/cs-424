# %%
install.packages("IRdisplay")
# Out:
# Installing package into 'C:/Users/hocho/OneDrive/Documents/R/win-library/3.6'
# (as 'lib' is unspecified)
# package 'IRdisplay' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\hocho\AppData\Local\Temp\RtmpY9jgnd\downloaded_packages

# %%
library("IRdisplay")
display_jpeg(file="img1.JPG")
